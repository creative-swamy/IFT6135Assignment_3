# %%
import JSD_Final as problem1
from matplotlib import pyplot as plt
import samplers
theta_initial = -1
theta_incremental = 0.1
number_of_models = 21
p_distribution = samplers.distribution1(0, 512)
JSD_Values = []
Theta_Values = []

for i in range(number_of_models):
    print("#####################", "Itteration",i+1, "######################################")
    q_distribution = samplers.distribution1(theta_initial, 512)
    JSD_M = problem1.JSD(hidden_size=64, mini_batch=512, learning_rate=0.0001, num_epochs=1000, print_interval=100)
    JSD_Values.append(JSD_M.run_main_loop(p_distribution, q_distribution))
    Theta_Values.append(theta_initial)
    theta_initial = theta_initial + theta_incremental
    
plt.plot(Theta_Values, JSD_Values, label='JSD')
plt.legend()
plt.show()
print( "Training complete" )
# Out:
# ##################### Itteration 1 ######################################
# Epoch    100. WD -0.0740958
# Epoch    200. WD -0.1526337
# Epoch    300. WD -0.2458032
# Epoch    400. WD -0.3408576
# Epoch    500. WD -0.4220846
# Epoch    600. WD -0.4927253
# Epoch    700. WD -0.5457711
# Epoch    800. WD -0.5817797
# Epoch    900. WD -0.6117460
# Epoch   1000. WD -0.6309712
# ##################### Itteration 2 ######################################
# Epoch    100. WD -0.1173721
# Epoch    200. WD -0.2087557
# Epoch    300. WD -0.3051232
# Epoch    400. WD -0.3951701
# Epoch    500. WD -0.4762008
# Epoch    600. WD -0.5301418
# Epoch    700. WD -0.5711714
# Epoch    800. WD -0.6063089
# Epoch    900. WD -0.6223965
# Epoch   1000. WD -0.6413967
# ##################### Itteration 3 ######################################
# Epoch    100. WD -0.0610793
# Epoch    200. WD -0.1414964
# Epoch    300. WD -0.2371649
# Epoch    400. WD -0.3275698
# Epoch    500. WD -0.4226399
# Epoch    600. WD -0.4917293
# Epoch    700. WD -0.5496163
# Epoch    800. WD -0.5872355
# Epoch    900. WD -0.6137830
# Epoch   1000. WD -0.6316791
# ##################### Itteration 4 ######################################
# Epoch    100. WD -0.0541105
# Epoch    200. WD -0.1352062
# Epoch    300. WD -0.2158932
# Epoch    400. WD -0.3013060
# Epoch    500. WD -0.3852804
# Epoch    600. WD -0.4612709
# Epoch    700. WD -0.5203849
# Epoch    800. WD -0.5688603
# Epoch    900. WD -0.6032053
# Epoch   1000. WD -0.6255521
# ##################### Itteration 5 ######################################
# Epoch    100. WD -0.0770962
# Epoch    200. WD -0.1614852
# Epoch    300. WD -0.2561558
# Epoch    400. WD -0.3507983
# Epoch    500. WD -0.4362740
# Epoch    600. WD -0.4999730
# Epoch    700. WD -0.5540439
# Epoch    800. WD -0.5922514
# Epoch    900. WD -0.6164216
# Epoch   1000. WD -0.6361827
# ##################### Itteration 6 ######################################
# Epoch    100. WD -0.0504109
# Epoch    200. WD -0.1086352
# Epoch    300. WD -0.1849562
# Epoch    400. WD -0.2754040
# Epoch    500. WD -0.3683756
# Epoch    600. WD -0.4478533
# Epoch    700. WD -0.5112833
# Epoch    800. WD -0.5617565
# Epoch    900. WD -0.5960860
# Epoch   1000. WD -0.6217307
# ##################### Itteration 7 ######################################
# Epoch    100. WD -0.0543965
# Epoch    200. WD -0.1075416
# Epoch    300. WD -0.1684636
# Epoch    400. WD -0.2420895
# Epoch    500. WD -0.3188995
# Epoch    600. WD -0.3985736
# Epoch    700. WD -0.4682424
# Epoch    800. WD -0.5254620
# Epoch    900. WD -0.5698018
# Epoch   1000. WD -0.6007889
# ##################### Itteration 8 ######################################
# Epoch    100. WD -0.0389572
# Epoch    200. WD -0.0810921
# Epoch    300. WD -0.1409099
# Epoch    400. WD -0.2114361
# Epoch    500. WD -0.2909315
# Epoch    600. WD -0.3771631
# Epoch    700. WD -0.4525521
# Epoch    800. WD -0.5131608
# Epoch    900. WD -0.5602155
# Epoch   1000. WD -0.5930114
# ##################### Itteration 9 ######################################
# Epoch    100. WD -0.0232742
# Epoch    200. WD -0.0519934
# Epoch    300. WD -0.0937597
# Epoch    400. WD -0.1488922
# Epoch    500. WD -0.2145531
# Epoch    600. WD -0.2891149
# Epoch    700. WD -0.3649409
# Epoch    800. WD -0.4293159
# Epoch    900. WD -0.4844393
# Epoch   1000. WD -0.5288684
# ##################### Itteration 10 ######################################
# Epoch    100. WD -0.0136815
# Epoch    200. WD -0.0285699
# Epoch    300. WD -0.0512323
# Epoch    400. WD -0.0802929
# Epoch    500. WD -0.1203814
# Epoch    600. WD -0.1656352
# Epoch    700. WD -0.2146844
# Epoch    800. WD -0.2666855
# Epoch    900. WD -0.3197190
# Epoch   1000. WD -0.3705440
# ##################### Itteration 11 ######################################
# Epoch    100. WD -0.0001795
# Epoch    200. WD 0.0002198
# Epoch    300. WD -0.0000086
# Epoch    400. WD 0.0000541
# Epoch    500. WD 0.0001495
# Epoch    600. WD -0.0000575
# Epoch    700. WD -0.0001194
# Epoch    800. WD 0.0001916
# Epoch    900. WD -0.0000422
# Epoch   1000. WD 0.0001280
# ##################### Itteration 12 ######################################
# Epoch    100. WD -0.0161399
# Epoch    200. WD -0.0323217
# Epoch    300. WD -0.0546879
# Epoch    400. WD -0.0913258
# Epoch    500. WD -0.1379768
# Epoch    600. WD -0.1998647
# Epoch    700. WD -0.2614922
# Epoch    800. WD -0.3238196
# Epoch    900. WD -0.3798348
# Epoch   1000. WD -0.4316280
# ##################### Itteration 13 ######################################
# Epoch    100. WD -0.0190554
# Epoch    200. WD -0.0463488
# Epoch    300. WD -0.0851758
# Epoch    400. WD -0.1451064
# Epoch    500. WD -0.2148657
# Epoch    600. WD -0.2853167
# Epoch    700. WD -0.3610839
# Epoch    800. WD -0.4278779
# Epoch    900. WD -0.4856523
# Epoch   1000. WD -0.5307174
# ##################### Itteration 14 ######################################
# Epoch    100. WD -0.0314142
# Epoch    200. WD -0.0897992
# Epoch    300. WD -0.1529036
# Epoch    400. WD -0.2229646
# Epoch    500. WD -0.3133981
# Epoch    600. WD -0.3962781
# Epoch    700. WD -0.4690906
# Epoch    800. WD -0.5238076
# Epoch    900. WD -0.5674825
# Epoch   1000. WD -0.5993372
# ##################### Itteration 15 ######################################
# Epoch    100. WD -0.0432484
# Epoch    200. WD -0.0994647
# Epoch    300. WD -0.1782249
# Epoch    400. WD -0.2655255
# Epoch    500. WD -0.3555608
# Epoch    600. WD -0.4354471
# Epoch    700. WD -0.4950586
# Epoch    800. WD -0.5493177
# Epoch    900. WD -0.5891091
# Epoch   1000. WD -0.6139335
# ##################### Itteration 16 ######################################
# Epoch    100. WD -0.0451784
# Epoch    200. WD -0.1118194
# Epoch    300. WD -0.1867128
# Epoch    400. WD -0.2716886
# Epoch    500. WD -0.3621688
# Epoch    600. WD -0.4399938
# Epoch    700. WD -0.5076507
# Epoch    800. WD -0.5546916
# Epoch    900. WD -0.5898909
# Epoch   1000. WD -0.6169134
# ##################### Itteration 17 ######################################
# Epoch    100. WD -0.0715358
# Epoch    200. WD -0.1479157
# Epoch    300. WD -0.2312875
# Epoch    400. WD -0.3221850
# Epoch    500. WD -0.4089435
# Epoch    600. WD -0.4844913
# Epoch    700. WD -0.5420440
# Epoch    800. WD -0.5822358
# Epoch    900. WD -0.6117826
# Epoch   1000. WD -0.6308460
# ##################### Itteration 18 ######################################
# Epoch    100. WD -0.0406005
# Epoch    200. WD -0.1216995
# Epoch    300. WD -0.2136787
# Epoch    400. WD -0.3086118
# Epoch    500. WD -0.3999539
# Epoch    600. WD -0.4759696
# Epoch    700. WD -0.5339828
# Epoch    800. WD -0.5730582
# Epoch    900. WD -0.6084482
# Epoch   1000. WD -0.6268066
# ##################### Itteration 19 ######################################
# Epoch    100. WD -0.1141760
# Epoch    200. WD -0.2222554
# Epoch    300. WD -0.3349587
# Epoch    400. WD -0.4284307
# Epoch    500. WD -0.5042349
# Epoch    600. WD -0.5595570
# Epoch    700. WD -0.5988559
# Epoch    800. WD -0.6231684
# Epoch    900. WD -0.6409110
# Epoch   1000. WD -0.6542939
# ##################### Itteration 20 ######################################
# Epoch    100. WD -0.0851754
# Epoch    200. WD -0.1816343
# Epoch    300. WD -0.2848008
# Epoch    400. WD -0.3852419
# Epoch    500. WD -0.4681633
# Epoch    600. WD -0.5270513
# Epoch    700. WD -0.5743446
# Epoch    800. WD -0.6074550
# Epoch    900. WD -0.6300962
# Epoch   1000. WD -0.6479602
# ##################### Itteration 21 ######################################
# Epoch    100. WD -0.1017020
# Epoch    200. WD -0.1980641
# Epoch    300. WD -0.3036239
# Epoch    400. WD -0.4008792
# Epoch    500. WD -0.4834846
# Epoch    600. WD -0.5453572
# Epoch    700. WD -0.5902919
# Epoch    800. WD -0.6187586
# Epoch    900. WD -0.6389753
# Epoch   1000. WD -0.6543882
# Training complete
